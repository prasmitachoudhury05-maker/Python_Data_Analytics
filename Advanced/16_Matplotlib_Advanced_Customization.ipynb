# %%
# Importing Libraries
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(
    lambda x: ast.literal_eval(x) if pd.notna(x) else x
)

# %%
df = df[df['job_title_short'] == 'Data Analyst']

# %%
# Data Analyst jobs only
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# Remove rows with no salary
df_DA = df_DA.dropna(subset=['salary_year_avg'])

# One skill per row
df_DA = df_DA.explode('job_skills')

# Calculate statistics
skills_stats = df_DA.groupby('job_skills').agg(
    skill_count=('job_skills', 'count'),
    median_salary=('salary_year_avg', 'median')
)

# Top 10 most common skills
skills_stats = skills_stats.sort_values(
    by='skill_count',
    ascending=False
).head(10)

# %% [markdown]
# Customizing our chart from 12_Exercise

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

df_DA['job_posted_month_no'] = df_DA['job_posted_date'].dt.month

df_DA_explode = df_DA.explode('job_skills')

# %%
df_DA_pivot = df_DA_explode.pivot_table(index='job_posted_month_no', columns='job_skills', aggfunc='size', fill_value=0)

df_DA_pivot.loc['Total'] = df_DA_pivot.sum()

df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending = False).index]

df_DA_pivot = df_DA_pivot.drop('Total')

# %%
df_DA_pivot
# Out:
# job_skills             sql  excel  python  tableau  power bi     r   sas  \
# job_posted_month_no
# 1                    11336   8170    6606     5596      4285  3607  3830
# 2                     7947   5772    4751     3936      3307  2576  2634
# 3                     7868   5675    4741     4051      3176  2650  2554
# 4                     7553   5496    4557     3776      3106  2399  2598
# 5                     6617   4773    4070     3245      2695  2093  1940
# 6                     7584   5724    4707     3812      3275  2442  2174
# 7                     7687   5513    4831     3928      3350  2444  2118
# 8                     8823   6482    5576     4533      3859  2975  2560
# 9                     6829   4886    4229     3446      3118  2146  1880
# 10                    7474   5217    4693     3709      3340  2380  2114
# 11                    6652   4776    4233     3284      3012  2159  1738
# 12                    6058   4376    4196     3139      2857  2125  1858
#
# job_skills           powerpoint  word   sap  ...  angular.js  xamarin  gtx  \
# job_posted_month_no                          ...
# 1                          1880  1778  1251  ...           2        0    0
# 2                          1291  1235   954  ...           0        0    0
# 3                          1266  1203   892  ...           0        1    0
# 4                          1190  1177   947  ...           0        0    0
# 5                           979   957   851  ...           0        0    0
# 6                          1173  1237   987  ...           0        0    0
# 7                          1096  1069   996  ...           0        0    1
# 8                          1332  1298  1117  ...           0        0    0
# 9                           944   945   852  ...           0        0    0
# 10                          955   990   872  ...           0        1    0
# 11                          894   887   808  ...           0        0    0
# 12                          822   786   753  ...           0        0    0
#
# job_skills           nuxt.js  ovh  esquisse  suse  capacitor  chainer  \
# job_posted_month_no
# 1                          1    0         0     0          1        0
# 2                          0    0         0     0          0        0
# 3                          0    0         0     1          0        0
# 4                          0    1         0     0          0        0
# 5                          0    0         0     0          0        0
# 6                          0    0         0     0          0        0
# 7                          0    0         0     0          0        0
# 8                          0    0         0     0          0        0
# 9                          0    0         0     0          0        0
# 10                         0    0         0     0          0        0
# 11                         0    0         1     0          0        0
# 12                         0    0         0     0          0        1
#
# job_skills           msaccess
# job_posted_month_no
# 1                           0
# 2                           0
# 3                           0
# 4                           0
# 5                           1
# 6                           0
# 7                           0
# 8                           0
# 9                           0
# 10                          0
# 11                          0
# 12                          0
#
# [12 rows x 235 columns]

# %%
df_DA_pivot.iloc[:, :5].plot(
    kind = 'line',
    linewidth = 4,
    linestyle = '--',
    colormap = 'viridis',
    marker = 'o',
    markersize = 7,
    figsize = (10,7)
)

plt.title('Top 5 Skills for Data Analyts per Month')
plt.ylabel('Count')
plt.xlabel('')
plt.show()

# %% [markdown]
# Customizing our Scatter plot from 15_Scatter_Plot

# %%
# Explode the 'job_skills' into individual rows
df_exploded = df_DA.explode('job_skills')

# Calculate the average salary and count of job postings per skill
skill_stats = df_exploded.groupby('job_skills').agg(
    median_salary=('salary_year_avg', 'median'),
    skill_count=('job_skills', 'count')
)

# Limit to the top skills
skill_count = 20

skill_stats = skill_stats.sort_values(
    by='skill_count',
    ascending=False
).head(skill_count)

skill_stats
# Out:
#             median_salary  skill_count
# job_skills
# sql          92500.000000        92428
# excel        84479.000000        66860
# python       98500.000000        57190
# tableau      95000.000000        46455
# power bi     90000.000000        39380
# r            92527.500000        29996
# sas          90000.000000        27998
# powerpoint   85000.000000        13822
# word         80000.000000        13562
# sap          90000.000000        11280
# azure       100000.000000        10913
# oracle       95000.000000        10387
# aws         100500.000000         9047
# sql server   92150.000000         8288
# go           90000.000000         7905
# flow         94450.000000         7259
# vba          90000.000000         6841
# looker      104000.000000         6259
# snowflake   110240.109375         6178
# qlik        100000.000000         5681

# %%
! pip install adjustText
# Out:
# Requirement already satisfied: adjustText in c:\users\aman\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: numpy in c:\users\aman\anaconda3\lib\site-packages (from adjustText) (2.3.5)
# Requirement already satisfied: matplotlib in c:\users\aman\anaconda3\lib\site-packages (from adjustText) (3.10.6)
# Requirement already satisfied: scipy in c:\users\aman\anaconda3\lib\site-packages (from adjustText) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aman\anaconda3\lib\site-packages (from matplotlib->adjustText) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\aman\anaconda3\lib\site-packages (from matplotlib->adjustText) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aman\anaconda3\lib\site-packages (from matplotlib->adjustText) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aman\anaconda3\lib\site-packages (from matplotlib->adjustText) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\aman\anaconda3\lib\site-packages (from matplotlib->adjustText) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\aman\anaconda3\lib\site-packages (from matplotlib->adjustText) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aman\anaconda3\lib\site-packages (from matplotlib->adjustText) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aman\anaconda3\lib\site-packages (from matplotlib->adjustText) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\aman\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.17.0)

# %%
from adjustText import adjust_text
import matplotlib.pyplot as plt

skill_stats.plot(
    kind='scatter',
    x='skill_count',
    y='median_salary'
)

ax = plt.gca()

texts = []

for i, txt in enumerate(skill_stats.index):
    texts.append(
        ax.text(
            skill_stats['skill_count'].iloc[i],
            skill_stats['median_salary'].iloc[i],
            txt
        )
    )

adjust_text(
    texts,
    arrowprops=dict(
        arrowstyle='->',
        color='gray'
    )
)

ax.yaxis.set_major_formatter(
    plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K')
)

plt.xlabel('Count of Job Postings')
plt.ylabel('Median Yearly Salary')
plt.title(f'Salary vs. Count of Job Postings for Top {skill_count} Skills')

plt.tight_layout()
plt.show()
